# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "../data/raw/flights_sample_3m.csv"

df = pd.read_csv(file_path, nrows=100000)  # Load only 100k rows

df.head()
# Out:
#       FL_DATE                AIRLINE                AIRLINE_DOT AIRLINE_CODE  \
# 0  2019-01-09  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 1  2022-11-19   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 2  2022-07-22  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 3  2023-03-06   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 4  2020-02-23       Spirit Air Lines       Spirit Air Lines: NK           NK
#
#    DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# 0     19977       1562    FLL  Fort Lauderdale, FL  EWR
# 1     19790       1149    MSP      Minneapolis, MN  SEA
# 2     19977        459    DEN           Denver, CO  MSP
# 3     19790       2295    MSP      Minneapolis, MN  SFO
# 4     20416        407    MCO          Orlando, FL  DFW
#
#                DEST_CITY  ...  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  \
# 0             Newark, NJ  ...       0.0             186.0         176.0
# ...

# %%
df.shape
# Out:
# (100000, 32)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FL_DATE                  100000 non-null  str
#  1   AIRLINE                  100000 non-null  str
#  2   AIRLINE_DOT              100000 non-null  str
#  3   AIRLINE_CODE             100000 non-null  str
#  4   DOT_CODE                 100000 non-null  int64
#  5   FL_NUMBER                100000 non-null  int64
#  6   ORIGIN                   100000 non-null  str
#  7   ORIGIN_CITY              100000 non-null  str
#  8   DEST                     100000 non-null  str
#  9   DEST_CITY                100000 non-null  str
#  10  CRS_DEP_TIME             100000 non-null  int64
#  11  DEP_TIME                 97443 non-null   float64
#  12  DEP_DELAY                97442 non-null   float64
#  13  TAXI_OUT                 97414 non-null   float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_CODE          97404
# DELAY_DUE_LATE_AIRCRAFT    82239
# DELAY_DUE_CARRIER          82239
# DELAY_DUE_SECURITY         82239
# DELAY_DUE_NAS              82239
# DELAY_DUE_WEATHER          82239
# ARR_DELAY                   2795
# ELAPSED_TIME                2795
# AIR_TIME                    2795
# WHEELS_ON                   2619
# ARR_TIME                    2619
# TAXI_IN                     2619
# WHEELS_OFF                  2586
# TAXI_OUT                    2586
# DEP_DELAY                   2558
# DEP_TIME                    2557
# CRS_ELAPSED_TIME               2
# DEST_CITY                      0
# CRS_DEP_TIME                   0
# DEST                           0
# DOT_CODE                       0
# FL_NUMBER                      0
# ORIGIN                         0
# ORIGIN_CITY                    0
# AIRLINE                        0
# AIRLINE_DOT                    0
# FL_DATE                        0
# AIRLINE_CODE                   0
# ...

# %%
df.describe()
# Out:
#             DOT_CODE      FL_NUMBER   CRS_DEP_TIME      DEP_TIME  \
# count  100000.000000  100000.000000  100000.000000  97443.000000
# mean    19978.891840    2520.166180    1326.080990   1328.665969
# std       376.551364    1744.103441     486.246477    499.715908
# min     19393.000000       1.000000       1.000000      1.000000
# 25%     19790.000000    1066.000000     914.000000    915.000000
# 50%     19930.000000    2164.000000    1317.000000   1321.000000
# 75%     20368.000000    3794.000000    1730.000000   1738.000000
# max     20452.000000    8814.000000    2359.000000   2400.000000
#
#           DEP_DELAY      TAXI_OUT    WHEELS_OFF     WHEELS_ON       TAXI_IN  \
# count  97442.000000  97414.000000  97414.000000  97381.000000  97381.000000
# mean      10.195162     16.655614   1350.619552   1460.863659      7.723827
# std       49.936879      9.184579    501.372051    527.244581      6.314710
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_CODE          97404
# DELAY_DUE_LATE_AIRCRAFT    82239
# DELAY_DUE_CARRIER          82239
# DELAY_DUE_SECURITY         82239
# DELAY_DUE_NAS              82239
# DELAY_DUE_WEATHER          82239
# ARR_DELAY                   2795
# ELAPSED_TIME                2795
# AIR_TIME                    2795
# WHEELS_ON                   2619
# ARR_TIME                    2619
# TAXI_IN                     2619
# WHEELS_OFF                  2586
# TAXI_OUT                    2586
# DEP_DELAY                   2558
# DEP_TIME                    2557
# CRS_ELAPSED_TIME               2
# DEST_CITY                      0
# CRS_DEP_TIME                   0
# DEST                           0
# DOT_CODE                       0
# FL_NUMBER                      0
# ORIGIN                         0
# ORIGIN_CITY                    0
# AIRLINE                        0
# AIRLINE_DOT                    0
# FL_DATE                        0
# AIRLINE_CODE                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FL_DATE                  100000 non-null  str
#  1   AIRLINE                  100000 non-null  str
#  2   AIRLINE_DOT              100000 non-null  str
#  3   AIRLINE_CODE             100000 non-null  str
#  4   DOT_CODE                 100000 non-null  int64
#  5   FL_NUMBER                100000 non-null  int64
#  6   ORIGIN                   100000 non-null  str
#  7   ORIGIN_CITY              100000 non-null  str
#  8   DEST                     100000 non-null  str
#  9   DEST_CITY                100000 non-null  str
#  10  CRS_DEP_TIME             100000 non-null  int64
#  11  DEP_TIME                 97443 non-null   float64
#  12  DEP_DELAY                97442 non-null   float64
#  13  TAXI_OUT                 97414 non-null   float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_CODE          97404
# DELAY_DUE_LATE_AIRCRAFT    82239
# DELAY_DUE_CARRIER          82239
# DELAY_DUE_SECURITY         82239
# DELAY_DUE_NAS              82239
# DELAY_DUE_WEATHER          82239
# ARR_DELAY                   2795
# ELAPSED_TIME                2795
# AIR_TIME                    2795
# WHEELS_ON                   2619
# ARR_TIME                    2619
# TAXI_IN                     2619
# WHEELS_OFF                  2586
# TAXI_OUT                    2586
# DEP_DELAY                   2558
# DEP_TIME                    2557
# CRS_ELAPSED_TIME               2
# DEST_CITY                      0
# CRS_DEP_TIME                   0
# DEST                           0
# DOT_CODE                       0
# FL_NUMBER                      0
# ORIGIN                         0
# ORIGIN_CITY                    0
# AIRLINE                        0
# AIRLINE_DOT                    0
# FL_DATE                        0
# AIRLINE_CODE                   0
# ...

# %%
# Fill delay-related nulls with 0
delay_columns = [
    'ARR_DELAY', 'DEP_DELAY', 'TAXI_OUT', 'TAXI_IN',
    'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT'
]

for col in delay_columns:
    if col in df.columns:
        df[col] = df[col].fillna(0)

df.isnull().sum().sort_values(ascending=False).head()
# Out:
# CANCELLATION_CODE    97404
# DELAY_DUE_CARRIER    82239
# DELAY_DUE_NAS        82239
# DELAY_DUE_WEATHER    82239
# AIR_TIME              2795
# dtype: int64

# %%
# Create route column
df['ROUTE'] = df['ORIGIN'] + "-" + df['DEST']

# Extract hour from scheduled departure time
df['DEP_HOUR'] = df['CRS_DEP_TIME'] // 100

df.head()
# Out:
#       FL_DATE                AIRLINE                AIRLINE_DOT AIRLINE_CODE  \
# 0  2019-01-09  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 1  2022-11-19   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 2  2022-07-22  United Air Lines Inc.  United Air Lines Inc.: UA           UA
# 3  2023-03-06   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL
# 4  2020-02-23       Spirit Air Lines       Spirit Air Lines: NK           NK
#
#    DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# 0     19977       1562    FLL  Fort Lauderdale, FL  EWR
# 1     19790       1149    MSP      Minneapolis, MN  SEA
# 2     19977        459    DEN           Denver, CO  MSP
# 3     19790       2295    MSP      Minneapolis, MN  SFO
# 4     20416        407    MCO          Orlando, FL  DFW
#
#                DEST_CITY  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0             Newark, NJ  ...         176.0     153.0    1065.0
# ...

# %%
df.to_csv("../data/processed/flights_cleaned_sample.csv", index=False)
